# %% [markdown]
# # 1. Load Data

# %%
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pmdarima as pm
import math
import os
import warnings
warnings.filterwarnings('ignore')

from math import sqrt
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.stats.diagnostic import het_arch
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from pylab import rcParams

from pmdarima import auto_arima
from statsmodels.tsa.seasonal import seasonal_decompose

import random

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, Bidirectional

import tensorflow as tf
from sklearn.metrics import r2_score
from tensorflow.python.util import deprecation
deprecation._PRINT_DEPRECATION_WARNINGS = False # to hide warnings during training stage

# %%
# Set stable random
def set_seed(seed: int = 42) -> None:
    np.random.seed(seed)
    random.seed(seed)

    # Set a fixed value for the hash seed
    os.environ["PYTHONHASHEED"] = str(seed)
    print(f"Random seed set as {seed}")

set_seed()
# Out:
# Random seed set as 42

# %%
# Import dataset
data = pd.read_csv('/Users/hominhtrung/Documents/Ai_final/VNIndex.csv', index_col=0)

# %% [markdown]
# # 2. EDA

# %%
# Check the first 5 rows of the data set
data.head()
# Out:
#          time    open    high     low   close    volume
# 0  2014-01-02  505.61  506.71  503.04  504.51  57717674
# 1  2014-01-03  504.41  506.19  503.94  505.37  55600438
# 2  2014-01-06  505.74  509.10  504.28  509.10  68738380
# 3  2014-01-07  511.02  513.00  509.87  510.12  74363638
# 4  2014-01-08  511.03  514.20  509.01  513.90  70296940

# %%
# Check the data type of data fields
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2607 entries, 0 to 2606
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   time    2607 non-null   object
#  1   open    2607 non-null   float64
#  2   high    2607 non-null   float64
#  3   low     2607 non-null   float64
#  4   close   2607 non-null   float64
#  5   volume  2607 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 142.6+ KB

# %% [markdown]
# However, at the time the data is imported into the ipynb file, the data fields still have the datatype object. Therefore, the team will clean the data before proceeding with further processing.

# %% [markdown]
# ## 2.1. Cleaning Data

# %% [markdown]
# The data cleaning process includes converting the datatype of the columns to the appropriate types.

# %%
# Change the data fields to the appropriate datatype
data['time'] = pd.to_datetime(data['time'])

# %%
# Convert datatype of Vol. to float by removing "M" and multiplying by 10^6 to get the correct units
data['volume'] = data['volume'].astype(float)

# %%
data.head()
# Out:
#         time    open    high     low   close      volume
# 0 2014-01-02  505.61  506.71  503.04  504.51  57717674.0
# 1 2014-01-03  504.41  506.19  503.94  505.37  55600438.0
# 2 2014-01-06  505.74  509.10  504.28  509.10  68738380.0
# 3 2014-01-07  511.02  513.00  509.87  510.12  74363638.0
# 4 2014-01-08  511.03  514.20  509.01  513.90  70296940.0

# %% [markdown]
# ## 2.2. Exploring Dataset and Explaination

# %% [markdown]
# ### 2.2.1. Check the quality of the dataset

# %% [markdown]
# The HPG stock price dataset does not include null values, does not possess duplicate values, and the date column is completely unique. From there, in terms of quality, the data set has no problem.

# %%
# Check the number of rows and columns of the data set
data.shape
# Out:
# (2607, 6)

# %%
# Check the number of null observations
print(data.isnull().sum())
# Out:
# time      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %%
# Check the number of duplicate observations
print("Number of duplicate observations: " + data.duplicated().sum().astype(str))
# Out:
# Number of duplicate observations: 0

# %%
# Check the number of unique values ​​of each data field
data.nunique()
# Out:
# time      2607
# open      2550
# high      2560
# low       2549
# close     2556
# volume    2607
# dtype: int64

# %% [markdown]
# ### 2.2.2. Check the fields in the dataset

# %% [markdown]
# ####2.2.2.1. Descriptive Analysis

# %% [markdown]
# - Descriptive Statistics data fields in a data set

# %%
data.describe()
# Out:
#                                 time         open         high          low  \
# count                           2607  2607.000000  2607.000000  2607.000000
# mean   2019-04-01 02:19:11.668584704   925.687453   931.461404   919.102267
# min              2014-01-02 00:00:00   504.410000   506.190000   503.040000
# 25%              2016-08-22 12:00:00   659.460000   663.775000   655.515000
# 50%              2019-04-03 00:00:00   952.970000   959.280000   947.710000
# 75%              2021-11-06 12:00:00  1124.710000  1129.995000  1116.295000
# max              2024-06-20 00:00:00  1534.100000  1536.450000  1524.960000
# std                              NaN   271.201908   272.858148   268.600170
#
#              close        volume
# count  2607.000000  2.607000e+03
# mean    925.601212  3.579714e+08
# min     504.510000  5.043514e+07
# 25%     659.520000  1.278087e+08
# 50%     952.770000  1.897561e+08
# 75%    1123.780000  5.931845e+08
# max    1528.570000  1.708948e+09
# std     270.879208  3.066643e+08

# %% [markdown]
# Examining the dataset, the authors gain insights into the "Price" variable. On average, the stock price of HPG is approximately 19249 VND, with a significant variation indicated by a standard deviation of 9780 VND.
#
# To better understand the price distribution, the authors look at the quartiles. The median price figure is 19249 VND, showing that half of the stock generates below this amount while the other half exceeds it. Notably, there are outliers, with close prices ranging from a minimum of 7411 VND to a maximum of 43895 VND. These extremes may result from specific company circumstances, highlighting the diverse issues that businesses face.

# %% [markdown]
# - Determine outlier (if exists) and perform descriptive statistics on observations with outlier values ​​in data fields

# %%
# A statistical function that describes observations that are outliers for each field in a data field
def outlier_detection(data, columns):
    result_df = pd.DataFrame(index=data.describe().index)  # Initialize with the same index as 'data'
    for col in columns:
        IQR = data[col].quantile(0.75) - data[col].quantile(0.25)
        lower_bound = data[col].quantile(0.25) - 1.5 * IQR
        upper_bound = data[col].quantile(0.75) + 1.5 * IQR
        # Finding ourliers
        outlier_condition = (data[col] < lower_bound) | (data[col] > upper_bound)
        outliers = data.loc[outlier_condition, col].describe()
        # Create an additional column for each outlier statistic of the data fields
        result_df[f'outlier_{col}'] = outliers
    return result_df

outlier_detection(data, data.columns)
# Out:
#       outlier_time  outlier_open  outlier_high  outlier_low  outlier_close  \
# count            0           0.0           0.0          0.0            0.0
# mean           NaT           NaN           NaN          NaN            NaN
# min            NaT           NaN           NaN          NaN            NaN
# 25%            NaT           NaN           NaN          NaN            NaN
# 50%            NaT           NaN           NaN          NaN            NaN
# 75%            NaT           NaN           NaN          NaN            NaN
# max            NaT           NaN           NaN          NaN            NaN
# std            NaN           NaN           NaN          NaN            NaN
#
#        outlier_volume
# count    1.800000e+01
# mean     1.418818e+09
# min      1.295576e+09
# 25%      1.344930e+09
# 50%      1.385554e+09
# 75%      1.455758e+09
# max      1.708948e+09
# std      1.185669e+08

# %% [markdown]
# From there we can see that the data fields related to prices have an insignificant number of outliers (from 14-20/1308 observations accounting for 1.07%-1.53%, almost negligible).
#
# However, the team will still process outliers according to each respective model instead of eliminating these outlier observations because that would corrupt the nature of the data set.

# %% [markdown]
# ### 2.2.3. Explore data fields

# %% [markdown]
# #### 2.2.3.1. Explore stock price data fields

# %%
# A line graph shows the price of a stock over time
dfl = pd.melt(data[['time', 'open', 'high', 'low']], ['time'])

plt.figure(figsize=(16, 6))
sns.lineplot(data = dfl,
             x = 'time',
             y = 'value',
             hue = 'variable')
plt.title('VNIndex Over Time')
plt.xlabel('Date')
plt.ylabel('VNIndex')
plt.show()

# %% [markdown]
# Based on the chart above, we can see that revenue fluctuated a lot from 2018 to 2023, and there must be many factors affecting this fluctuation. Let's analyze this fluctuation more closely through the analysis of the reasons below and build a model to evaluate and predict the close price of HPG stock.

# %% [markdown]
# #### 2.2.3.2. Stock Price Trend Explaination ( Focus on 2022 )
# The stock price trend showed that from 2018 to 2020, the price just remained stable under 20 thousand VND but in 2021, the price skyrocketed to nearly 40 thousand VND then dropped strongly through 2022 to 2023. In this report, we focus on 2022 because it is the year that has many important geopolitical events that still affect the steel consumption and HPG stock price this year.
#
#     Q1: Stock prices increased sharply
# This is due to the fact that steel consumption in the Vietnamese market as a whole and Hoa Phat in particular only reached its highest level in Q1 and declined in the following three quarters, leading to the highest stock price in Q1. Specifically, in 2022, the Vietnamese real estate market started quite excitedly in early 2022, leading to an increase in demand for construction steel (Hoa Phat 2022 Annual Report).
#
#     Q2: Sudden plunge in stock prices
# Stock prices plummeted from March to April due to the escalating tensions of the Russia-Ukraine war. Coal prices skyrocketed due to the geopolitical conflict crisis, coupled with the impact of sluggish consumption and low selling prices caused by weak demand, putting significant pressure on the cost of goods sold. The energy crisis stemming from the Russia-Ukraine war has tripled the price of coking coal, one of the two main raw materials for blast furnace steelmaking, to three times its usual level during the two peak periods of March and May 2022, leading to a rapid decline in stock prices. (Hoa Phat 2022 Annual Report; special.nhandan.vn)
#
#     Q3: Stock prices remained gloomy
# The high input material prices in Q2 were reflected in the steel production cost in Q3, leading to a significant increase in the cost of goods in inventory. Inflation and economic recession have weakened global steel demand, consequently affecting domestic demand and prices as well. Additionally, the domestic real estate market has been sluggish due to tightened credit in the sector, contributing to a significant decrease in steel consumption in Vietnam. In the third quarter, the average selling price of construction steel decreased by 3%, HRC (Hot Rolled Coil) by 26%, and products made from HRC, such as steel pipes and iron sheets, decreased by 17% and 20%, respectively, compared to the same period last year. Hòa Phát's consumption volume increased but could not offset the negative impact of selling prices, leading to a decline in revenue (vietnaminsider.com)
#
#     Q4: The stock price continued to drop
# The downturn in Vietnam's real estate market in the second half of 2022 caused a decline in domestic steel consumption compared to the same period in the previous year, which made the stock price of HPG continue to drop.

# %% [markdown]
# ####2.2.3.4: Univariate Analysis

# %% [markdown]
# In this section, our group will show the distribution chart of the four continuous variables : Price, Open, High, Low.

# %%
# Distribution of stock closing prices
fig, axes = plt.subplots(1, 4, figsize = (16,6))

sns.histplot(data['time'], kde=True, ax = axes[0])
axes[0].set_title('VNIndex Closing Distribution')

sns.histplot(data['open'], kde=True, ax = axes[1])
axes[1].set_title('VNIndex Opening Distribution')

sns.histplot(data['high'], kde=True, ax = axes[2])
axes[2].set_title('Distribution of VNIndex of Stock Day')

sns.histplot(data['low'], kde=True, ax = axes[3])
axes[3].set_title('Distribution of VNIndex of Stock Day')

plt.tight_layout()
plt.show()

# %% [markdown]
# Based on the charts above, we can see that the distribution is skewed to the left, so the majority of stock price per day is low around 10000 to 25000 USD; However there are still many days where stock price is at 25000 USD or higher or more, especially many days with stock price of more than 40000 USD. Therefore, the close price distribution is different within the HPG system.

# %% [markdown]
# Next our group will analyze the volume of shares exchanged by day through the line chart below.

# %%
# Line graph of the volume of shares exchanged by day
plt.figure(figsize=(16, 6))
sns.lineplot(data=data, x='time', y='volume')
plt.title('Volume of Shares Exchanged')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.show()

# %% [markdown]
# The line graph above provided shows the trading volume of shares from 2018 to 2023. It displays the fluctuations in trading activity over time, with various peaks indicating periods of high trading volume.

# %%
# Distribution Vol. of HPG stock
plt.figure(figsize=(10, 6))
sns.histplot(data['volume'], kde=True)
plt.title('Distribution Volume of Stock Exchanged')
plt.xlabel('Volumn')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Based on the histogram provided, it can be seen that the majority of stock trading occurs at low volume, with the highest frequency on the left side of the chart. This suggests that larger transactions are less common. The apparent decrease in frequency as volume increases may indicate that the market is highly liquid at low volume levels but declines as volume increases. This may also reflect the nature of investors participating in the market, with a large number of retail investors and fewer larger or institutional investors.

# %%
# Change % line graph of HPG stock by day
plt.figure(figsize=(16, 6))
sns.lineplot(data=data, x='Date', y='Change %')
plt.title('Change in Stock Value by Day')
plt.xlabel('Date')
plt.ylabel('Change (%)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Change % line graph of HPG stock by day
#       2 plt.figure(figsize=(16, 6))
# ----> 3 sns.lineplot(data=data, x='Date', y='Change %')
#       4 plt.title('Change in Stock Value by Day')
#       5 plt.xlabel('Date')
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/relational.py:618, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     615 errorbar = _deprecate_ci(errorbar, ci)
#     617 variables = _LinePlotter.get_semantics(locals())
# --> 618 p = _LinePlotter(
#     619     data=data, variables=variables,
#     620     estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     621     sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     622     legend=legend,
#     623 )
#     625 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     626 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/relational.py:365, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     351 def __init__(
#     352     self, *,
#     353     data=None, variables={},
#    (...)
#     359     # the kind of plot to draw, but for the time being we need to set
#     360     # this information so the SizeMapping can use it
#     361     self._default_size_range = (
#     362         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     363     )
# --> 365     super().__init__(data=data, variables=variables)
#     367     self.estimator = estimator
#     368     self.errorbar = errorbar
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:640, in VectorPlotter.__init__(self, data, variables)
#     635 # var_ordered is relevant only for categorical axis variables, and may
#     636 # be better handled by an internal axis information object that tracks
#     637 # such information and is set up by the scale_* methods. The analogous
#     638 # information for numeric axes would be information about log scales.
#     639 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640 self.assign_variables(data, variables)
#     642 for var, cls in self._semantic_mappings.items():
#     643
#     644     # Create the mapping function
#     645     map_func = partial(cls.map, plotter=self)
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:701, in VectorPlotter.assign_variables(self, data, variables)
#     699 else:
#     700     self.input_format = "long"
# --> 701     plot_data, variables = self._assign_variables_longform(
#     702         data, **variables,
#     703     )
#     705 self.plot_data = plot_data
#     706 self.variables = variables
#
# File /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:938, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     933 elif isinstance(val, (str, bytes)):
#     934
#     935     # This looks like a column name but we don't know what it means!
#     937     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 938     raise ValueError(err)
#     940 else:
#     941
#     942     # Otherwise, assume the value is itself data
#     943
#     944     # Raise when data object is present and a vector can't matched
#     945     if isinstance(data, pd.DataFrame) and not isinstance(val, pd.Series):
#
# ValueError: Could not interpret value `Date` for parameter `x`

# %% [markdown]
# The chart shows large stock price fluctuations from 2018 to 2023, with value fluctuations ranging from -6% to +6%. There is no clear upward or downward trend over time, but rather unpredictable and seemingly violent fluctuations. This may indicate that the stock has a high level of risk and that price fluctuations can be due to various factors such as news about the company, general market movements, or macroeconomic events.

# %% [markdown]
# ####2.2.3.4. Bivariate Analysis

# %%
# Correlation between variables except date
corr = data.drop('time', axis=1).corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# The relationship between the variables on the heatmap can be understood as follows:
#
# Price and Change %: The correlation coefficient is 0.016, indicating a veryweak relationship between stock price and percentage change. This may indicate that the stock price is not the main factor influencing short-term price changes.
#
# Open and Change %: The correlation coefficient is -0.021, a weak negative relationship. This may indicate that the opening price is not a reliable indicator of intraday price changes.
#
# High and Change %: The correlation coefficient is -0.0041, indicating that there is no clear relationship between the highest price of the day and the price change.
#
# Low and Change %: The correlation coefficient is -0.0043, similar to High and Change %, with no clear relationship.
#
# Overall, the very low correlation coefficients indicate that there is no strong relationship between these variables. In stock analysis, this can be understood to mean that factors such as stock price, opening price, high and low prices do not greatly influence the fluctuation of short-term price change percentage. This may also reflect the difficult forecasting nature of the stock market, where other factors aside.

# %% [markdown]
# The cleaned dataset is then exported to a separate file for convenience in future usages of our team in model building.

# %% [markdown]
# # 3. Model Building and Evalutions

# %% [markdown]
# ## 3.1. ARIMA

# %%
df = data.copy()

# %% [markdown]
# We set 'Date' in our dataframe as our main index so we can reduce the number of relevant preprocessing steps for the dataframe later on.

# %%
# Convert 'Date' to datetime and set as index
df.set_index('time', inplace=True)
df = df.sort_index(ascending=True)

df.head()
# Out:
#               open    high     low   close      volume
# time
# 2014-01-02  505.61  506.71  503.04  504.51  57717674.0
# 2014-01-03  504.41  506.19  503.94  505.37  55600438.0
# 2014-01-06  505.74  509.10  504.28  509.10  68738380.0
# 2014-01-07  511.02  513.00  509.87  510.12  74363638.0
# 2014-01-08  511.03  514.20  509.01  513.90  70296940.0

# %%
# Test for stationarity
def test_stationarity(timeseries):
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()

    # Plot rolling statistics:
    plt.figure(figsize=(12, 6))
    plt.plot(timeseries, color='blue', label='Original')
    plt.plot(rolmean, color='red', label='Rolling Mean')
    plt.plot(rolstd, color='black', label='Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean and Standard Deviation')
    plt.show()

    print("Results of Dickey-Fuller Test:")
    adft = adfuller(timeseries, autolag='AIC')

    # Output for dft will give us without defining what the values are.
    # Hence we manually write what values it explains using a for loop
    output = pd.Series(adft[0:4], index=['Test Statistic', 'p-value', 'No. of lags used', 'Number of observations used'])
    for key, value in adft[4].items():
        output['critical value (%s)' % key] = value
    print(output)

# Apply the stationarity test on the 'Price' column
test_stationarity(df['close'])
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                   -1.291231
# p-value                           0.633174
# No. of lags used                  2.000000
# Number of observations used    2604.000000
# critical value (1%)              -3.432864
# critical value (5%)              -2.862651
# critical value (10%)             -2.567361
# dtype: float64

# %% [markdown]
# The time series data visually exhibits a clear upward trend, indicating that the average stock price increases over time. This non-constant mean is a hallmark of non-stationarity. Further visual inspection reveals changing volatility, with price fluctuations becoming more pronounced in later periods. Statistical analysis using the Dickey-Fuller test confirms this non-stationarity, as the test statistic does not fall within the critical region, and the high p-value indicates a failure to reject the null hypothesis of a unit root. Therefore, both visual and statistical evidence strongly suggest that this stock price data is non-stationary and requires appropriate transformations before applying models like ARIMA.

# %%
df['close_diff'] = df['close'].diff().dropna()

# Plot the differenced series
plt.figure(figsize=(10, 6))
plt.plot(df['close_diff'], label='close_diff')
plt.title('Differenced Stock Price')
plt.xlabel('Date')
plt.ylabel('close_diff')
plt.legend()
plt.show()

# %% [markdown]
# The price changes oscillate around zero, suggesting a lack of a consistent direction in the stock's movement. While the changes appear largely random, there are periods of increased volatility clustered together, indicating that the stock's price is influenced by underlying market dynamics. A few extreme price changes (outliers) are also noticeable, likely due to significant events impacting the stock. Overall, the plot suggests the differenced stock price might be stationary, making it suitable for modeling with methods that assume stationarity, such as ARIMA.

# %%
result = seasonal_decompose(df['close'], model='multiplicative', period=30)
fig = plt.figure()
fig = result.plot()
fig.set_size_inches(16, 9)

# %% [markdown]
# A consistent seasonal pattern, though smaller in scale compared to the overall trend, indicates regular fluctuations that occur within specific time frames, possibly linked to calendar cycles or market events. The residual component, representing noise and unexplained variations, remains relatively minor, suggesting the trend and seasonal components effectively capture most of the price movements. Overall, the decomposition highlights the strong influence of long-term trends and recurring seasonal patterns on stock prices, with a limited impact from random fluctuations.

# %%
rcParams['figure.figsize'] = 10, 6

# Log transform the 'Price' column
df_log = np.log(df['close'])

# Calculate rolling mean and standard deviation
moving_avg = df_log.rolling(12).mean()
std_dev = df_log.rolling(12).std()

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(df_log, color='blue', label='Log Transformed Price')
plt.plot(moving_avg, color='red', label='Rolling Mean')
plt.plot(std_dev, color='black', label='Standard Deviation')
plt.legend(loc='best')
plt.title('Moving Average and Standard Deviation')
plt.show()

# %% [markdown]
# The plot reveals a clear upward trend in the log-transformed prices, indicating a non-constant mean over time, a hallmark of non-stationarity. The rolling mean closely tracks this trend, further confirming the presence of non-stationarity. Additionally, the rolling standard deviation fluctuates, suggesting that the variance of the data is not constant, further solidifying the non-stationary nature of the log-transformed stock prices.

# %%
# Log transform the 'Price' column
df_log = (df['close'])

# Ensure the 'Date' index is correctly set
df_log.index = df.index

training_data_len = int(np.ceil(len(df_log) - 365))

training_data_len
# Out:
# 2242

# %%
# Split the data into training and testing sets
train_data = df_log[:training_data_len]
test_data = df_log[training_data_len:]

# Plot the train and test data
plt.figure(figsize=(10, 6))
plt.grid(True)
plt.xlabel('Dates')
plt.ylabel('Log Transformed Closing Prices')
plt.plot(train_data, 'green', label='Train data')
plt.plot(test_data, 'blue', label='Test data')
plt.legend()
plt.title('Train and Test Data Split')
plt.show()

# %%
model = auto_arima(train_data, start_p=0, start_q=0,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0,
                      D=0,
                      trace=True,
                      error_action='ignore',
                      suppress_warnings=True,
                      stepwise=True)
print(model.summary())
model.plot_diagnostics(figsize=(15,8))
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=17244.708, Time=0.06 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=17242.046, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=17242.314, Time=0.15 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=17243.615, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=17242.081, Time=0.06 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=17240.758, Time=0.16 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=17242.721, Time=0.49 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=17242.721, Time=0.19 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=17242.190, Time=0.14 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=17244.722, Time=0.35 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=17239.450, Time=0.08 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=17241.150, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=17240.876, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=17241.410, Time=0.11 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=17241.410, Time=0.09 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=17240.982, Time=0.04 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=17240.866, Time=0.03 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=17243.410, Time=0.34 sec
#
# Best model:  ARIMA(1,1,1)(0,0,0)[0]
# Total fit time: 2.463 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 2242
# Model:               SARIMAX(1, 1, 1)   Log Likelihood               -8616.725
# Date:                Sun, 23 Jun 2024   AIC                          17239.450
# Time:                        18:05:47   BIC                          17256.594
# Sample:                             0   HQIC                         17245.709
#                                - 2242
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.7319      0.106      6.882      0.000       0.523       0.940
# ma.L1         -0.6907      0.113     -6.101      0.000      -0.913      -0.469
# sigma2       128.0251      1.897     67.474      0.000     124.306     131.744
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              4063.33
# Prob(Q):                              0.92   Prob(JB):                         0.00
# Heteroskedasticity (H):               7.28   Skew:                            -1.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.25
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# Diagnostic plots reveal that the residuals are roughly normally distributed with no significant autocorrelation, suggesting a reasonable fit of the model to the data.

# %%
# Create Datafram and format a new set of data
arima_df = data.filter(['time', 'close']).copy()
arima_df.index = pd.DatetimeIndex(arima_df).to_period('D')

# %%
# Split the new dataset into 2 parts: For training and for testing
arima_train, arima_test = arima_df[0:len(arima_df)-365] , arima_df[len(arima_df)-365:len(arima_df)]

# %%
# Conduct ADF Test to check the stationary of time series data
adf1 = adfuller(arima_df['close'], regression='c', maxlag=90)
print('ADF stat: ', adf1[0])
print('P - value: ', adf1[1])
# Out:
# ADF stat:  -1.2912314631416486
# P - value:  0.633174320964058

# %%
# Conduct ADF Test 2nd to check the stationary of time series data after differencing
adf2 = adfuller(np.diff(arima_df['close']), regression='n', maxlag=90)
print('ADF stat: ', adf2[0])
print('P - value: ', adf2[1])
# Out:
# ADF stat:  -34.18880082582441
# P - value:  0.0

# %%
# Initialize history with train_data prices
history = train_data.tolist()

# Initialize predictions list
predictions = []

# Walk-forward validation
for t in range(len(test_data)):
    model = ARIMA(history, order=(1, 1, 1))  # ARIMA(0,1,0) model
    model_fit = model.fit()
    output = model_fit.forecast(steps=1)  # Forecast next step only
    predictions.append(output[0])  # Store the prediction

    # Update history with observed Price from test_data
    obs = test_data.iloc[t]
    history.append(obs)

    print(f'predicted={output[0]:.2f}, expected={obs:.2f}')

# Convert predictions to a DataFrame
predictions_df = pd.DataFrame({'Date': test_data.index, 'Predicted_Price': predictions})
predictions_df.set_index('Date', inplace=True)
# Out:
# predicted=1015.85, expected=1009.29
# predicted=1009.15, expected=1007.09
# predicted=1006.90, expected=1043.90
# predicted=1045.29, expected=1046.35
# predicted=1047.41, expected=1055.82
# predicted=1056.95, expected=1051.44
# predicted=1052.03, expected=1054.21
# predicted=1054.73, expected=1053.35
# predicted=1053.67, expected=1055.76
# predicted=1056.08, expected=1056.39
# predicted=1056.64, expected=1060.17
# predicted=1060.50, expected=1066.68
# predicted=1067.17, expected=1088.29
# predicted=1089.53, expected=1098.28
# predicted=1099.57, expected=1108.08
# predicted=1109.39, expected=1117.10
# predicted=1118.40, expected=1102.57
# predicted=1102.83, expected=1111.18
# predicted=1111.74, expected=1075.97
# predicted=1074.84, expected=1077.59
# predicted=1076.90, expected=1077.15
# predicted=1076.66, expected=1089.29
# predicted=1089.46, expected=1065.84
# predicted=1064.99, expected=1072.22
# predicted=1071.90, expected=1064.03
# predicted=1063.47, expected=1055.30
# predicted=1054.56, expected=1043.70
# predicted=1042.70, expected=1038.64
# predicted=1037.74, expected=1048.20
# predicted=1047.98, expected=1058.29
# predicted=1058.56, expected=1059.31
# predicted=1059.54, expected=1086.69
# predicted=1088.00, expected=1082.23
# predicted=1082.93, expected=1054.28
# predicted=1053.60, expected=1053.66
# predicted=1053.18, expected=1039.56
# predicted=1038.65, expected=1021.25
# predicted=1019.85, expected=1024.68
# predicted=1023.89, expected=1040.55
# predicted=1040.69, expected=1037.61
# predicted=1037.58, expected=1024.77
# predicted=1024.22, expected=1027.18
# predicted=1026.91, expected=1037.84
# predicted=1038.10, expected=1049.18
# predicted=1049.83, expected=1055.95
# predicted=1056.67, expected=1053.00
# predicted=1053.35, expected=1052.80
# predicted=1053.03, expected=1040.13
# predicted=1039.75, expected=1062.19
# predicted=1062.85, expected=1047.40
# predicted=1047.24, expected=1045.14
# predicted=1044.94, expected=1023.10
# predicted=1022.07, expected=1032.43
# predicted=1032.12, expected=1040.54
# predicted=1040.66, expected=1045.10
# predicted=1045.36, expected=1046.79
# predicted=1047.03, expected=1052.25
# predicted=1052.63, expected=1054.29
# predicted=1054.63, expected=1056.33
# predicted=1056.64, expected=1059.44
# predicted=1059.77, expected=1064.64
# predicted=1065.07, expected=1079.28
# predicted=1080.17, expected=1078.45
# predicted=1079.01, expected=1080.86
# predicted=1081.34, expected=1070.91
# predicted=1070.83, expected=1069.71
# predicted=1069.60, expected=1065.35
# predicted=1065.10, expected=1069.46
# predicted=1069.46, expected=1069.45
# predicted=1069.45, expected=1064.30
# predicted=1064.09, expected=1052.89
# predicted=1052.29, expected=1053.81
# predicted=1053.44, expected=1055.02
# predicted=1054.82, expected=1048.98
# predicted=1048.60, expected=1049.25
# predicted=1049.01, expected=1042.91
# predicted=1042.49, expected=1041.36
# predicted=1041.02, expected=1034.85
# predicted=1034.35, expected=1040.80
# predicted=1040.71, expected=1039.63
# predicted=1039.52, expected=1049.12
# predicted=1049.43, expected=1040.61
# predicted=1040.47, expected=1040.31
# predicted=1040.21, expected=1053.44
# predicted=1053.90, expected=1053.77
# predicted=1054.09, expected=1058.26
# predicted=1058.66, expected=1057.12
# predicted=1057.34, expected=1066.90
# predicted=1067.44, expected=1065.71
# predicted=1066.03, expected=1065.91
# predicted=1066.13, expected=1060.44
# predicted=1060.37, expected=1068.31
# predicted=1068.58, expected=1067.07
# predicted=1067.20, expected=1070.64
# predicted=1070.87, expected=1065.85
# predicted=1065.81, expected=1061.79
# predicted=1061.60, expected=1064.63
# predicted=1064.62, expected=1063.76
# predicted=1063.72, expected=1074.98
# predicted=1075.40, expected=1078.05
# predicted=1078.46, expected=1075.17
# predicted=1075.33, expected=1078.39
# predicted=1078.63, expected=1090.84
# predicted=1091.50, expected=1097.82
# predicted=1098.55, expected=1108.31
# predicted=1109.23, expected=1109.54
# predicted=1110.21, expected=1101.32
# predicted=1101.44, expected=1107.53
# predicted=1107.86, expected=1116.02
# predicted=1116.59, expected=1122.46
# predicted=1123.11, expected=1117.42
# predicted=1117.65, expected=1116.97
# predicted=1117.11, expected=1115.22
# predicted=1115.24, expected=1105.40
# predicted=1105.02, expected=1111.72
# predicted=1111.72, expected=1118.46
# predicted=1118.73, expected=1125.30
# predicted=1125.76, expected=1129.38
# predicted=1129.86, expected=1132.03
# predicted=1132.46, expected=1134.33
# predicted=1134.71, expected=1138.35
# predicted=1138.77, expected=1125.39
# predicted=1125.15, expected=1120.18
# predicted=1119.80, expected=1125.50
# predicted=1125.46, expected=1132.00
# predicted=1132.24, expected=1134.62
# predicted=1134.89, expected=1126.22
# predicted=1126.06, expected=1138.07
# predicted=1138.44, expected=1149.02
# predicted=1149.71, expected=1151.77
# predicted=1152.35, expected=1154.20
# predicted=1154.69, expected=1165.42
# predicted=1166.21, expected=1168.40
# predicted=1169.06, expected=1173.13
# predicted=1173.77, expected=1174.09
# predicted=1174.56, expected=1172.98
# predicted=1173.25, expected=1172.81
# predicted=1172.99, expected=1185.90
# predicted=1186.56, expected=1190.72
# predicted=1191.36, expected=1195.90
# predicted=1196.55, expected=1200.84
# predicted=1201.49, expected=1197.33
# predicted=1197.63, expected=1207.67
# predicted=1208.30, expected=1222.90
# predicted=1223.96, expected=1217.56
# predicted=1218.07, expected=1220.43
# predicted=1220.90, expected=1210.95
# predicted=1210.88, expected=1225.98
# predicted=1226.55, expected=1241.42
# predicted=1242.44, expected=1242.23
# predicted=1242.97, expected=1233.99
# predicted=1234.16, expected=1220.61
# predicted=1220.18, expected=1232.21
# predicted=1232.39, expected=1236.84
# predicted=1237.15, expected=1234.05
# predicted=1234.15, expected=1243.26
# predicted=1243.70, expected=1233.48
# predicted=1233.39, expected=1177.99
# predicted=1175.66, expected=1179.76
# predicted=1178.27, expected=1180.49
# predicted=1179.50, expected=1172.56
# predicted=1171.55, expected=1189.39
# predicted=1189.39, expected=1183.37
# predicted=1183.13, expected=1201.72
# predicted=1202.30, expected=1204.43
# predicted=1204.93, expected=1213.16
# predicted=1213.85, expected=1224.05
# predicted=1224.96, expected=1234.98
# predicted=1236.04, expected=1245.50
# predicted=1246.66, expected=1243.14
# predicted=1243.81, expected=1241.48
# predicted=1241.86, expected=1223.63
# predicted=1223.13, expected=1245.44
# predicted=1246.01, expected=1238.39
# predicted=1238.49, expected=1223.81
# predicted=1223.29, expected=1227.36
# predicted=1227.15, expected=1211.81
# predicted=1211.04, expected=1211.50
# predicted=1210.97, expected=1226.11
# predicted=1226.34, expected=1212.74
# predicted=1212.36, expected=1193.05
# predicted=1192.01, expected=1153.20
# predicted=1150.80, expected=1137.96
# predicted=1135.66, expected=1153.85
# predicted=1153.05, expected=1152.43
# predicted=1151.84, expected=1154.15
# predicted=1153.83, expected=1155.25
# predicted=1155.09, expected=1118.10
# predicted=1116.43, expected=1128.67
# predicted=1127.98, expected=1113.89
# predicted=1112.81, expected=1128.54
# predicted=1128.40, expected=1137.36
# predicted=1137.63, expected=1143.69
# predicted=1144.13, expected=1150.81
# predicted=1151.40, expected=1151.61
# predicted=1152.04, expected=1154.73
# predicted=1155.15, expected=1141.42
# predicted=1141.16, expected=1121.65
# predicted=1120.66, expected=1103.40
# predicted=1101.96, expected=1087.85
# predicted=1086.22, expected=1108.03
# predicted=1107.84, expected=1093.53
# predicted=1092.79, expected=1105.90
# predicted=1105.93, expected=1101.66
# predicted=1101.50, expected=1055.45
# predicted=1053.46, expected=1060.62
# predicted=1059.49, expected=1042.40
# predicted=1040.88, expected=1028.19
# predicted=1026.54, expected=1039.66
# predicted=1039.02, expected=1075.47
# predicted=1076.59, expected=1076.78
# predicted=1077.57, expected=1089.66
# predicted=1090.72, expected=1080.29
# predicted=1080.58, expected=1113.43
# predicted=1115.00, expected=1113.89
# predicted=1114.94, expected=1101.68
# predicted=1101.86, expected=1100.07
# predicted=1100.12, expected=1109.73
# predicted=1110.16, expected=1122.50
# predicted=1123.31, expected=1125.53
# predicted=1126.19, expected=1101.19
# predicted=1100.63, expected=1103.66
# predicted=1103.39, expected=1110.46
# predicted=1110.56, expected=1113.82
# predicted=1114.02, expected=1088.49
# predicted=1087.61, expected=1095.61
# predicted=1095.32, expected=1088.06
# predicted=1087.57, expected=1095.43
# predicted=1095.39, expected=1102.80
# predicted=1103.07, expected=1094.13
# predicted=1093.97, expected=1102.16
# predicted=1102.37, expected=1120.49
# predicted=1121.35, expected=1115.97
# predicted=1116.36, expected=1126.43
# predicted=1127.10, expected=1121.49
# predicted=1121.74, expected=1124.44
# predicted=1124.72, expected=1125.50
# predicted=1125.73, expected=1127.63
# predicted=1127.87, expected=1114.20
# predicted=1113.83, expected=1110.13
# predicted=1109.72, expected=1102.30
# predicted=1101.72, expected=1091.88
# predicted=1091.08, expected=1096.30
# predicted=1095.95, expected=1100.76
# predicted=1100.71, expected=1102.43
# predicted=1102.46, expected=1103.06
# predicted=1103.11, expected=1117.66
# predicted=1118.27, expected=1122.25
# predicted=1122.83, expected=1121.99
# predicted=1122.36, expected=1128.93
# predicted=1129.45, expected=1129.93
# predicted=1130.31, expected=1131.72
# predicted=1132.04, expected=1144.17
# predicted=1144.88, expected=1150.72
# predicted=1151.45, expected=1154.68
# predicted=1155.32, expected=1160.19
# predicted=1160.84, expected=1158.59
# predicted=1158.95, expected=1161.54
# predicted=1161.90, expected=1162.22
# predicted=1162.48, expected=1154.70
# predicted=1154.57, expected=1154.12
# predicted=1154.01, expected=1163.12
# predicted=1163.41, expected=1162.53
# predicted=1162.70, expected=1169.06
# predicted=1169.43, expected=1181.50
# predicted=1182.25, expected=1182.86
# predicted=1183.41, expected=1177.50
# predicted=1177.64, expected=1172.97
# predicted=1172.88, expected=1170.37
# predicted=1170.21, expected=1175.67
# predicted=1175.78, expected=1175.69
# predicted=1175.76, expected=1179.65
# predicted=1179.86, expected=1164.31
# predicted=1163.83, expected=1173.02
# predicted=1173.05, expected=1172.55
# predicted=1172.55, expected=1186.06
# predicted=1186.60, expected=1188.48
# predicted=1188.93, expected=1198.53
# predicted=1199.23, expected=1202.50
# predicted=1203.12, expected=1209.70
# predicted=1210.40, expected=1224.97
# predicted=1226.06, expected=1230.06
# predicted=1230.99, expected=1230.04
# predicted=1230.65, expected=1227.31
# predicted=1227.60, expected=1212.00
# predicted=1211.56, expected=1224.17
# predicted=1224.38, expected=1237.46
# predicted=1238.14, expected=1254.55
# predicted=1255.70, expected=1252.73
# predicted=1253.41, expected=1258.28
# predicted=1258.96, expected=1261.41
# predicted=1261.99, expected=1269.98
# predicted=1270.72, expected=1262.73
# predicted=1262.92, expected=1268.46
# predicted=1268.82, expected=1247.35
# predicted=1246.73, expected=1235.49
# predicted=1234.58, expected=1245.00
# predicted=1244.80, expected=1270.51
# predicted=1271.41, expected=1264.26
# predicted=1264.60, expected=1263.78
# predicted=1263.98, expected=1243.56
# predicted=1242.88, expected=1242.46
# predicted=1241.97, expected=1260.08
# predicted=1260.46, expected=1276.42
# predicted=1277.33, expected=1281.80
# predicted=1282.61, expected=1267.86
# predicted=1267.83, expected=1282.21
# predicted=1282.76, expected=1283.09
# predicted=1283.49, expected=1290.18
# predicted=1290.72, expected=1284.09
# predicted=1284.21, expected=1281.52
# predicted=1281.49, expected=1287.04
# predicted=1287.24, expected=1271.47
# predicted=1270.99, expected=1268.25
# predicted=1267.80, expected=1255.11
# predicted=1254.29, expected=1250.35
# predicted=1249.62, expected=1262.82
# predicted=1262.84, expected=1258.56
# predicted=1258.41, expected=1258.20
# predicted=1258.08, expected=1276.60
# predicted=1277.26, expected=1216.61
# predicted=1214.80, expected=1215.68
# predicted=1214.42, expected=1193.01
# predicted=1191.27, expected=1174.85
# predicted=1172.93, expected=1190.22
# predicted=1189.55, expected=1177.40
# predicted=1176.43, expected=1205.61
# predicted=1206.06, expected=1204.97
# predicted=1205.25, expected=1209.52
# predicted=1209.88, expected=1216.36
# predicted=1216.86, expected=1221.03
# predicted=1221.54, expected=1241.58
# predicted=1242.71, expected=1248.63
# predicted=1249.66, expected=1250.46
# predicted=1251.21, expected=1248.64
# predicted=1249.06, expected=1244.70
# predicted=1244.82, expected=1240.18
# predicted=1240.08, expected=1243.28
# predicted=1243.34, expected=1254.39
# predicted=1254.86, expected=1268.78
# predicted=1269.65, expected=1273.11
# predicted=1273.85, expected=1277.58
# predicted=1278.25, expected=1277.14
# predicted=1277.56, expected=1266.91
# predicted=1266.78, expected=1281.03
# predicted=1281.50, expected=1261.93
# predicted=1261.50, expected=1267.68
# predicted=1267.62, expected=1281.73
# predicted=1282.23, expected=1272.64
# predicted=1272.62, expected=1266.32
# predicted=1266.07, expected=1261.72
# predicted=1261.38, expected=1280.00
# predicted=1280.46, expected=1283.52
# predicted=1283.96, expected=1284.35
# predicted=1284.68, expected=1283.56
# predicted=1283.75, expected=1287.58
# predicted=1287.86, expected=1290.67
# predicted=1290.97, expected=1284.41
# predicted=1284.37, expected=1300.19
# predicted=1300.76, expected=1301.51
# predicted=1301.94, expected=1279.91
# predicted=1279.39, expected=1274.77
# predicted=1274.23, expected=1279.50
# predicted=1279.32, expected=1279.79
# predicted=1279.68, expected=1282.30

# %%
# Plot the actual vs predicted prices
plt.figure(figsize=(12, 6))
plt.plot(train_data.index, train_data, label='Training Data')
plt.plot(test_data.index, test_data, color='blue', label='Actual Price')
plt.plot(predictions_df.index, predictions_df['Predicted_Price'], color='orange', label='Predicted Price')
plt.fill_between(predictions_df.index, test_data, predictions_df['Predicted_Price'], color='k', alpha=0.1)
plt.title('Stock Price Prediction with ARIMA(0,1,0)')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score

def calculate_metrics(y_true, y_pred):
    # Calculate R-squared
    r_squared = r2_score(y_true, y_pred)

    # Calculate MAPE
    def mean_absolute_percentage_error(y_true, y_pred):
        y_true, y_pred = np.array(y_true), np.array(y_pred)
        return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

    mape = mean_absolute_percentage_error(y_true, y_pred)

    # Calculate RMSE
    rmse = np.sqrt(np.mean((y_pred - y_true) ** 2))

    # Create metrics DataFrame
    metrics_df = pd.DataFrame({
        'R-squared': [r_squared],
        'MAPE': [mape],
        'RMSE': [rmse]
    }, index=['ARIMA'])

    return metrics_df

# Example usage with your ARIMA predictions and test_data
metrics_df = calculate_metrics(test_data, predictions)

# Print the metrics DataFrame
print(metrics_df)
# Out:
#        R-squared      MAPE       RMSE
# ARIMA   0.978253  0.740022  11.832528

# %% [markdown]
# ## 3.2. LSTM Model

# %% [markdown]
# ## Model Preprocessing

# %% [markdown]
# The model is preprocessed in these particular steps:
# * Create a copy of the original data
# * Sort the data by `Date` for easy appending and splitting operations later on
# * Select only the `Date` and `Price` columns as these are the columns we are interested in predicting
# * Converting the DataFrame into a numpy array to fit within the LSTM model

# %%
np.random.seed(42)
# Creating a copy of the original data
VNI = data.copy()

# Sort the data by Date
VNI = VNI.sort_values(by=['time'])

# Filter out only 'Date' and 'Price' columns
VNI_subset = VNI[['close']]

# Convert the DataFrame to a numpy array
VNI_LSTM = VNI_subset.filter(['close']).values

# Check the data for correct coding
VNI_subset.head()
# Out:
#     close
# 0  504.51
# 1  505.37
# 2  509.10
# 3  510.12
# 4  513.90

# %% [markdown]
# As we are interested in building a model that can predict stock prices even in the circumstance that extreme external conditions are affecting the dataset, we decide to keep the last 365 days to use as the test dataset. This number will only take up 27.9% of the dataset which is acceptable. Furthermore, the last year within this dataset has witness extreme changes in stock price. That is why we want to use the last year as testing data.

# %%
# Calculating the number of rows remaining after subtracting the last 365 rows for testing
training_data_len = int(np.ceil( len(VNI_LSTM) - 365 ))

training_data_len
# Out:
# 2242

# %%
# Data scaling with MinMaxScaler()
MMS = MinMaxScaler()
scaled_data = MMS.fit_transform(VNI_LSTM)
scaled_data
# Out:
# array([[0.        ],
#        [0.00083979],
#        [0.00448216],
#        ...,
#        [0.75678183],
#        [0.75706502],
#        [0.75951604]])

# %%
# Create the training dataset previously scaled
train_data = scaled_data[0:int(training_data_len), :]
train_data
# Out:
# array([[0.        ],
#        [0.00083979],
#        [0.00448216],
#        ...,
#        [0.46940609],
#        [0.48831123],
#        [0.49914068]])

# %% [markdown]
# The data will then be split into `x_train` and `y_train` with the idea that for any values $i$ in `y_train`, the model will use values from $i - 1$ to $i - size$ to predict that particular value, or a sliding window approach.
#
# The team has tried various `size` values (30, 60, 90, etc) and found that 15 days work best. The reason is becase of the large fluctuations of stock price due to events such as the COVID-19 or various wars across the globe. Because of that, looking to far into the past yields little value for the model.
#
# The data is then converted into numpy arrays and reshaped to fit into the LSTM model.

# %%
# Spliting the train data into x_train and y_train
x_train = []
y_train = []
size = 15

for i in range(size, len(train_data)):
    x_train.append(train_data[i-size:i, 0])
    y_train.append(train_data[i, 0])

# Convert training data into numpy arrays to fit into the model
x_train, y_train = np.array(x_train), np.array(y_train)

# Reshape the data
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
x_train.shape
# Out:
# (2227, 15, 1)

# %%
# Create the test dataset
test_data = scaled_data[training_data_len - size: , :]

# Split the data sets x_test and y_test with similar ideas to the train dataset
x_test = []
y_test = VNI_LSTM[training_data_len:, :]
for i in range(size, len(test_data)):
    x_test.append(test_data[i-size:i, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))
x_test.shape
# Out:
# (365, 15, 1)

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Bidirectional, Dense
from tensorflow.keras.optimizers import Adam, RMSprop
from sklearn.model_selection import train_test_split

# Define the hyperparameters to tune
param_dist = {
    'optimizer': ['adam', 'rmsprop'],
    'epochs': [15, 30, 45],
    'batch_size': [16, 32, 64]
}

# Create a function to build the model
def create_model(optimizer):
    model = Sequential()
    model.add(LSTM(128, return_sequences=True, input_shape=(x_train.shape[1], 1)))
    model.add(Bidirectional(LSTM(64, return_sequences=False)))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer=optimizer)
    return model

# Prepare data
# Assuming x_train and y_train are already defined
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.25, random_state=42)

# Function to get optimizer
def get_optimizer(name):
    if name == 'adam':
        return Adam()
    elif name == 'rmsprop':
        return RMSprop()

# Initialize variables to store the best score and parameters
best_score = float('inf')
best_params = None

# Perform random search
for _ in range(10):  # n_iter = 10
    # Randomly sample hyperparameters
    optimizer_name = np.random.choice(param_dist['optimizer'])
    optimizer = get_optimizer(optimizer_name)
    epochs = np.random.choice(param_dist['epochs'])
    batch_size = np.random.choice(param_dist['batch_size'])
    
    # Build and train the model
    model = create_model(optimizer)
    model.fit(x_train, y_train, epochs=epochs, batch_size=batch_size, verbose=0, validation_data=(x_val, y_val))
    
    # Evaluate the model
    score = model.evaluate(x_val, y_val, verbose=0)
    
    # Update best score and parameters
    if score < best_score:
        best_score = score
        best_params = {
            'optimizer': optimizer_name,
            'epochs': epochs,
            'batch_size': batch_size
        }

# Print the best score and best parameters
print("Best: %f using %s" % (best_score, best_params))
# Out:
# Best: 0.000260 using {'optimizer': 'adam', 'epochs': 15, 'batch_size': 16}

# %% [markdown]
# ## Model Training

# %% [markdown]
# We have tuned the data based on multiple rounds of trial and errors and we have decided on these hyperparameters:
# * 2 layers model: The data is complex instead of exihibiting a stable trend so we will need 2 layers instead of 1.the
# * `batch_size = 32`: This is generally considered  default value for `batch_size`.
# * `optimizer = 'adam'`: `adam` is a well-known and widely used optimizer.
# * `loss = 'mean_squared_error'`: This is used as MRSE is one of the criteria required by Business Case to evaluate the two models

# %%
# LSTM model
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape= (x_train.shape[1], 1)))
model.add(Bidirectional(LSTM(64, return_sequences=False)))
model.add(Dense(32))
model.add(Dense(1))

# %%
model.summary()
# Out:
# Model: "sequential_21"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_42 (LSTM)                  │ (None, 15, 128)        │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_21                │ (None, 128)            │        98,816 │
# │ (Bidirectional)                 │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_42 (Dense)                │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 169,537 (662.25 KB)
#  Trainable params: 169,537 (662.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile the model based on decided optimizer and loss function
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
np.random.seed(42)
model.fit(x_train, y_train, batch_size=16, epochs=45, validation_data=(x_val, y_val), callbacks=early_stopping)
# Out:
# Epoch 1/45
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.1457e-04 - val_loss: 1.2142e-04
# Epoch 2/45
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.4193e-04 - val_loss: 1.3222e-04
# Epoch 3/45
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.7379e-04 - val_loss: 2.5184e-04
# Epoch 4/45
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.5534e-04 - val_loss: 1.3451e-04
# Epoch 5/45
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.6574e-04 - val_loss: 3.5062e-04
# Epoch 6/45
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.2402e-04 - val_loss: 2.7077e-04
# Epoch 7/45
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6054e-04 - val_loss: 3.6333e-04
# Epoch 8/45
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.1016e-04 - val_loss: 2.1012e-04
# Epoch 9/45
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.2175e-04 - val_loss: 1.2359e-04
# Epoch 10/45
# 84/84 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.6228e-04 - val_loss: 2.2145e-04

# %% [markdown]
# ### Model Testing

# %% [markdown]
# The test dataset is extracted and processed in a similar fashion as the traning

# %%
# Create the test dataset
test_data = scaled_data[training_data_len - size: , :]

# Split the data sets x_test and y_test with similar ideas to the train dataset
x_test = []
y_test = VNI_LSTM[training_data_len:, :]
for i in range(size, len(test_data)):
    x_test.append(test_data[i-size:i, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1 ))

# %%
# Predicted values of the model
predictions = model.predict(x_test)
predictions = MMS.inverse_transform(predictions)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# As requested by the Business Case 1 prompt, this model will be evaluated based on 3 metricsL: R-squared, MAPE, and RMSE. The team has calculated these values for this model.

# %%
# Calculate R-squared
r_squared = r2_score(y_test, predictions)

# Calculate MAPE
def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return str(np.mean(np.abs((y_true - y_pred) / y_true)) * 100)

# Calculate RMSE
rmse = np.sqrt(np.mean(((predictions - y_test) ** 2)))

# Merge results into a DataFrame
LSTM_metrics = pd.DataFrame({
    'R-squared': [r_squared],
    'MAPE': [mean_absolute_percentage_error(y_test, predictions)],
    'RMSE': [rmse]
}, index = ['LSTM'])

LSTM_metrics
# Out:
#       R-squared                MAPE       RMSE
# LSTM   0.977933  0.7300467636270634  11.919047

# %% [markdown]
# ### Results Visualization

# %% [markdown]
# To better understand LSTM results, the team decided to plot the predictions. Visually, the predictions are very accurate event within extreme price swings in 2022 and 2023. Therefore the model has successfully complete its goal of predicting stock prices even within extreme events.

# %%
# Ensure 'Date' is a datetime column
VNI['time'] = pd.to_datetime(VNI['time'])

# Create the training data used for plotting
viz_train = VNI[:training_data_len].copy()
viz_train.set_index('time', inplace=True)

# Create the testing and predictions data used for plotting
viz_test = VNI[training_data_len:].copy()
viz_test.set_index('time', inplace=True)
viz_test.insert(1, 'Predictions', predictions, True)

# %%
# Line Chart
plt.figure(figsize=(16,6))
plt.title('Stock Price Prediction with a 4 layers LSTM Model')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.plot(viz_train.index, viz_train['close'])
plt.plot(viz_test.index, viz_test[['close', 'Predictions']])
plt.legend(['Train', 'Test', 'Predictions'], loc='upper left')
plt.show()

# %%
combined_metrics = pd.concat([metrics_df, LSTM_metrics])

print("Models' Metrics Comparison:")
print(combined_metrics)
# Out:
# Models' Metrics Comparison:
#        R-squared                MAPE       RMSE
# ARIMA   0.978253            0.740022  11.832528
# LSTM    0.977933  0.7300467636270634  11.919047

# %%
last_date = '2024-06-20'
future_dates = pd.date_range(last_date, periods=365)
ticker='VNIndex'
#Get last 180 days values and convert into array
last_180_days=VNI_subset[-365:].values

#Scale the data to be values between 0
last_180_days_scaled=MMS.transform(last_180_days)

# Dự báo 180 ngày tiếp theo
time_step=365
input_data = last_180_days_scaled  # Lấy dữ liệu 180 ngày cuối
input_data = input_data.reshape((1, time_step, 1))

future_predictions = []
for _ in range(365):  # Dự báo 180 ngày tiếp theo
    prediction = model.predict(input_data)
    future_predictions.append(prediction[0, 0])
    # Chuyển đổi prediction thành đúng định dạng trước khi append
    input_data = np.append(input_data[:, 1:, :], np.reshape(prediction, (1, 1, 1)), axis=1)

future_predictions = MMS.inverse_transform(np.array(future_predictions).reshape(-1, 1))

# Tạo DataFrame để lưu kết quả dự báo với ngày
future_df = pd.DataFrame(future_predictions, index=future_dates, columns=['Predicted Value'])


# In ra kết quả dự báo
# print("Dự báo 180 ngày tiếp theo:", future_predictions.flatten())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step

# %%
future_df
# Out:
#             Predicted Value
# 2024-06-20      1283.319580
# 2024-06-21      1284.446655
# 2024-06-22      1285.591431
# 2024-06-23      1286.694092
# 2024-06-24      1287.758057
# ...                     ...
# 2025-06-15      1385.437378
# 2025-06-16      1385.592407
# 2025-06-17      1385.747437
# 2025-06-18      1385.902344
# 2025-06-19      1386.057861
#
# [365 rows x 1 columns]

# %%
# plt.plot(future_df.index, future_df.values, label='Actual Data')
# Line Chart
plt.figure(figsize=(16,6))
plt.title('Stock Price Prediction with Bidirectional-LSTM Model')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.plot(viz_train.index, viz_train['close'])
plt.plot(viz_test.index, viz_test[['close', 'Predictions']])
plt.plot(future_df.index, future_df.values, label='Future Predictions', color='red', linestyle='dashed')
plt.legend(['Train', 'Test', 'Predictions'], loc='upper left')
plt.legend()
plt.show()

# %%
# print("Dự báo 180 ngày tiếp theo:", future_predictions.flatten())
# Out:
# Dự báo 180 ngày tiếp theo: [1283.3196 1284.4467 1285.5914 1286.6941 1287.758  1288.7876 1289.7922
#  1290.7781 1291.7527 1292.7219 1293.6924 1294.6667 1295.6427 1296.6093
#  1297.5587 1298.4808 1299.3688 1300.2228 1301.0409 1301.8378 1302.6122
#  1303.3616 1304.0819 1304.7815 1305.4585 1306.1178 1306.7667 1307.4146
#  1308.0647 1308.712  1309.3499 1309.9703 1310.5546 1311.1029 1311.6257
#  1312.1248 1312.6115 1313.0981 1313.5845 1314.0657 1314.5464 1315.035
#  1315.5316 1316.0298 1316.522  1317.0034 1317.4731 1317.932  1318.3823
#  1318.8151 1319.2375 1319.6565 1320.0852 1320.5223 1320.9668 1321.4178
#  1321.8757 1322.3389 1322.8066 1323.2784 1323.7523 1324.2225 1324.6797
#  1325.1208 1325.5433 1325.9503 1326.3414 1326.7168 1327.0731 1327.4094
#  1327.7285 1328.0353 1328.3293 1328.6105 1328.882  1329.145  1329.4044
#  1329.6637 1329.9275 1330.1956 1330.4689 1330.7455 1331.0312 1331.3269
#  1331.6271 1331.9315 1332.2385 1332.5474 1332.8534 1333.1564 1333.4578
#  1333.7596 1334.0596 1334.3583 1334.6565 1334.9586 1335.2694 1335.5912
#  1335.9261 1336.2716 1336.629  1337.0021 1337.39   1337.7876 1338.1902
#  1338.5929 1338.9961 1339.4026 1339.8096 1340.2119 1340.607  1340.9973
#  1341.3839 1341.7712 1342.1654 1342.5652 1342.968  1343.3705 1343.7701
#  1344.165  1344.5535 1344.936  1345.321  1345.7135 1346.1138 1346.5216
#  1346.9402 1347.3756 1347.8237 1348.2821 1348.7507 1349.2291 1349.7131
#  1350.202  1350.6952 1351.1947 1351.7036 1352.2233 1352.7498 1353.2823
#  1353.8196 1354.3613 1354.9093 1355.4579 1356.0018 1356.5426 1357.0808
#  1357.6189 1358.1472 1358.6577 1359.1478 1359.6207 1360.0775 1360.5111
#  1360.9158 1361.2877 1361.6202 1361.9241 1362.225  1362.529  1362.8429
#  1363.1738 1363.5206 1363.8868 1364.267  1364.6594 1365.0592 1365.4587
#  1365.8492 1366.2227 1366.5762 1366.9093 1367.2228 1367.5056 1367.7579
#  1367.9807 1368.1709 1368.3303 1368.4524 1368.5264 1368.5547 1368.5483
#  1368.5276 1368.4996 1368.459  1368.4053 1368.3363 1368.2557 1368.1803
#  1368.1104 1368.052  1367.998  1367.9408 1367.8715 1367.7805 1367.6598
#  1367.5027 1367.3115 1367.0957 1366.8647 1366.6228 1366.3616 1366.0826
#  1365.7784 1365.4556 1365.1383 1364.8337 1364.5607 1364.3339 1364.1498
#  1363.9946 1363.8661 1363.7596 1363.6741 1363.592  1363.5122 1363.4393
#  1363.372  1363.3029 1363.223  1363.1317 1363.0392 1362.9435 1362.8411
#  1362.7344 1362.6362 1362.5476 1362.4744 1362.4149 1362.3689 1362.3407
#  1362.3247 1362.3125 1362.3025 1362.2882 1362.2689 1362.2406 1362.2002
#  1362.1467 1362.0867 1362.025  1361.9696 1361.9291 1361.9055 1361.9001
#  1361.9158 1361.9531 1362.0072 1362.0771 1362.1641 1362.2662 1362.3851
#  1362.5195 1362.6638 1362.8147 1362.9689 1363.1243 1363.2808 1363.4375
#  1363.5963 1363.7625 1363.9371 1364.1183 1364.3059 1364.4958 1364.6816
#  1364.8624 1365.0409 1365.2202 1365.4027 1365.588  1365.7777 1365.975
#  1366.189  1366.4213 1366.6736 1366.9436 1367.2314 1367.5344 1367.8514
#  1368.1783 1368.5085 1368.84   1369.1738 1369.5159 1369.8739 1370.2445
#  1370.6212 1370.9972 1371.3712 1371.7394 1372.0978 1372.4424 1372.7739
#  1373.0938 1373.4131 1373.7385 1374.0653 1374.3848 1374.6993 1375.0134
#  1375.3379 1375.6738 1376.0138 1376.3505 1376.6818 1377.0098 1377.3273
#  1377.6302 1377.9137 1378.1772 1378.4177 1378.6321 1378.8241 1378.995
#  1379.149  1379.2842 1379.3928 1379.4716 1379.5127 1379.5127 1379.4941
#  1379.4644 1379.4408 1379.436  1379.4526 1379.4971 1379.5621 1379.6501
#  1379.7605 1379.8914 1380.039  1380.1938 1380.3522 1380.5128 1380.6777
#  1380.8512 1381.037  1381.2351 1381.4403 1381.646  1381.8489 1382.0463
#  1382.2385 1382.4279 1382.6122 1382.799  1382.9854 1383.1681 1383.3524
#  1383.5438 1383.7428 1383.9434 1384.1438 1384.3435 1384.542  1384.7365
#  1384.9259 1385.1094 1385.2794 1385.4374 1385.5924 1385.7474 1385.9023
#  1386.0579]
